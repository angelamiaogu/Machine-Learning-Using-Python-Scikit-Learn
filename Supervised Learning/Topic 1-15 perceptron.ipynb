# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 6.3 MB/s eta 0:00:00a 0:00:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/angelasthingy/Desktop/Machine Learning Using Python Scikit Learn/ang_ML/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
def load_data():
    URL_='https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
    data = pd.read_csv(URL_, header = None)
    return data


data = load_data()
data.columns = ['petal_length', 'petal_width', 'sepal_length', 'sepal_width', 'class']
data
# Out:
#      petal_length  petal_width  sepal_length  sepal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# please plot data with patel legnt ahd sepal length and hue will be the the class

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def load_data():
    URL_='https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
    data = pd.read_csv(URL_, header=None)
    return data

# Load and process data
data = load_data()
data.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# Plotting
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='petal_length', y='sepal_length', hue='class')
plt.title('Petal Length vs Sepal Length')
plt.xlabel('Petal Length')
plt.ylabel('Sepal Length')
plt.show()

# %%
x = data [['petal_length', 'sepal_length']] # features
y = data ['class'] # target

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron

# %%
model = Perceptron()
model.fit(x,y)
# Out:
# Perceptron()

# %%
model.predict([[6.5,7.5]])
# Out:
# /Users/angelasthingy/Desktop/Machine Learning Using Python Scikit Learn/ang_ML/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# array(['Iris-virginica'], dtype='<U15')

# %%
model.predict([[1,3]])
# Out:
# /Users/angelasthingy/Desktop/Machine Learning Using Python Scikit Learn/ang_ML/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# array(['Iris-setosa'], dtype='<U15')
