# %% [markdown]
# ## y(w,x) = wo + w1*x1 + w2*x2 + ..... + wp*xp

# %%
pip install numpy
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/angelasthingy/Desktop/Machine Learning Using Python Scikit Learn/ang_ML/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/angelasthingy/Desktop/Machine Learning Using Python Scikit Learn/ang_ML/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip3 install -U scikit-learn scipy matplotlib
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/angelasthingy/Desktop/Machine Learning Using Python Scikit Learn/ang_ML/bin/python -m pip install --upgrade pip' command.

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg
# Out:
# LinearRegression()

# %%
x = [
    [0, 0],
    [1, 1],
    [2, 2]
]
y = [0, 1, 2]

# %%
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
reg.predict([[100, 100]])
# Out:
# array([100.])

# %%
reg.predict([[0, 2]])
# Out:
# array([1.])

# %%
reg.coef_
# Out:
# array([0.5, 0.5])

# %%
####### Linear REgression example ended

# %% [markdown]
# # m2 Ridge model

# %%
from sklearn import linear_model
angela = linear_model.Ridge(alpha=0.5)

angela
# Out:
# Ridge(alpha=0.5)

# %%
x = [
    [0, 0],
    [0, 0.5],
    [1, 1]
]
y = [0, 0.1, 1]

# %%
angela.fit(x, y)
# Out:
# Ridge(alpha=0.5)

# %%
angela.predict([[1, 1]])
# Out:
# array([0.79090909])

# %%
angela.coef_
# Out:
# array([0.41818182, 0.29090909])

# %%
####################### Ridge Regression example ended

# %%
## LASSO is lienar regression with L1 regularization
from sklearn import linear_model
model = linear_model.Lasso(alpha=0.1)

# %%
x = [
    [0, 0],
    [1,1],
    [0,1],
    [1,0]
]
y = [0, 1, 1, 0]

# %%
model.fit(x,y)
# Out:
# Lasso(alpha=0.1)

# %%
model.predict([[1,0]])
# Out:
# array([0.2])

# %%
# simple example of converting data to gaussian shape
marks = np.arange(90,100,0.01)
import numpy as np
marks = np.array(marks)
from scipy.stats import norm

marks_g = norm.pdf(marks,90,1)



#relative marking?

# %%
import matplotlib.pyplot as plt

plt.plot(marks_g)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the mean and standard deviation of the distribution
mu = 0
sigma = 1

# Generate x values for the plot
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

# Calculate the probability density function (PDF) for the Gaussian distribution
y = norm.pdf(x, mu, sigma)

# Plot the Gaussian curve
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Gaussian Distribution')
plt.show()
